# %% [markdown]
# ## Calculate OLR versus $T_s$ with radiative-convective atmospheres

# %% [markdown]
# ### Import things
# This assumes that SOCRATES is installed at `AGNI/socrates/`. Modify this as required.

# %%
# Set directory
ROOT_DIR = abspath(joinpath(pwd(),"../"))
ENV["RAD_DIR"] = joinpath(ROOT_DIR,"socrates")
# Out:
# "/Users/nichollsh/Projects/AGNI/socrates"

# %%
# Import system packages
using Printf
using Plots

# Import AGNI
using AGNI
import AGNI.atmosphere as atmosphere
import AGNI.solver as nl
import AGNI.dump as dump
import AGNI.plotting as plotting

# Use Normal-level logging from AGNI module
AGNI.setup_logging("",1)
# Out:
# [ Info: Precompiling AGNI [ede838c1-9ec3-4ebe-8ae8-da4091b3f21c]

# %% [markdown]
# ### Define atmosphere parameters

# %%
# Configuration options
instellation    = 1360.0  # Solar constant [W m-2]
gravity         = 9.81
radius          = 6.37e6
nlev_centre     = 35
p_surf          = 270.0     # bar
t_surf          = 3000.0
p_top           = 1e-5      # bar 
mole_fractions  = Dict([("H2O", 1.0)])
condensates     = ["H2O"]

spectral_file = joinpath(ROOT_DIR,"res/spectral_files/Frostflow/48/Frostflow.sf")
star_file     = joinpath(ROOT_DIR,"res/stellar_spectra/sun.txt");

# %%
# Create output directory
output_dir = "/tmp/agni_notebook/"
rm(output_dir,force=true,recursive=true)
mkdir(output_dir);

# %% [markdown]
# ### Initialise the atmosphere

# %%
# Setup atmosphere
atmos = atmosphere.Atmos_t()
atmosphere.setup!(atmos, ROOT_DIR, output_dir, 
                        spectral_file,
                        instellation, 0.375, 0.0, 48.19,
                        t_surf,  
                        gravity, radius,
                        nlev_centre, p_surf, p_top,
                        mf_dict=mole_fractions,
                        condensates=condensates,
                        flag_gcontinuum=true,
                        thermo_functions=false,
                        flag_rayleigh=true
                        )
atmosphere.allocate!(atmos, star_file)
# Out:
# [ INFO  ] Composition set by dict
# [ INFO  ] Inserting stellar spectrum and Rayleigh coefficients
# [ INFO  ] Allocated atmosphere with composition
# [ INFO  ]     1.00e+00 H2O   (CNDSBLE)

# %% [markdown]
# ### Run the model for a high-temperature case
# This provides an initial guess from which later simulations will be initialised

# %%
atmos.tmp_surf = 3050.0
atmos.tmpl[:] .= 3050
atmos.tmp[:] .= 3050;

# %%
solver_success = nl.solve_energy!(atmos, 
                                    sol_type=1,         # Conserve energy, but with fixed surface temperature
                                    sens_heat=true,    # Do not include sensible heat transport
                                    latent=true,        # Include condensation
                                    method=1,           # Use the Newton-Raphson method
                                    dx_max=400.0,       # Allow large step sizes because of the poor initial guess
                                    linesearch=true ,   # Enable Linesearch
                                    save_frames=false, modplot=1, # disable plotting 
                                    conv_atol=0.1
                                    )
println("Solver success? $solver_success")
# Out:
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 3050.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]        1  -2.97e+04  1.072e+06  3.197e+06  +2.87e+03  +3.05e+03  4.000e+02  C2-Nr
# [ INFO  ]        2  -1.55e+04  6.168e+05  1.867e+06  +2.64e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        3  -1.03e+04  3.210e+05  9.852e+05  +2.39e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        4  -4.62e+03  1.550e+05  4.864e+05  +2.14e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        5  -2.30e+03  7.922e+04  2.474e+05  +1.90e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        6  -1.20e+03  3.958e+04  1.237e+05  +1.62e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        7  -1.19e+03  2.279e+04  6.966e+04  +1.30e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        8  -5.17e+02  1.768e+04  5.264e+04  +1.18e+03  +3.05e+03  1.909e+02  C2-Nr-Ls
# [ INFO  ]        9  -4.67e+02  1.603e+04  4.799e+04  +1.16e+03  +3.05e+03  6.239e+01  C2-Nr-Ls
# [ INFO  ]       10  -6.76e+02  1.500e+04  4.501e+04  +1.15e+03  +3.05e+03  4.851e+01  C2-Nr-Ls
# [ INFO  ]       11  -6.62e+02  1.240e+04  3.749e+04  +1.10e+03  +3.05e+03  1.136e+02  C2-Nr-Ls
# [ INFO  ]       12  -4.46e+02  1.038e+04  3.153e+04  +1.07e+03  +3.05e+03  1.093e+02  C2-Nr-Ls
# [ INFO  ]       13  -2.68e+02  8.521e+03  2.594e+04  +1.03e+03  +3.05e+03  1.186e+02  C2-Nr-Ls
# [ INFO  ]       14  -2.02e+02  6.666e+03  2.054e+04  +9.69e+02  +3.05e+03  1.257e+02  C2-Nr-Ls
# [ INFO  ]       15  -1.38e+02  4.961e+03  1.565e+04  +9.29e+02  +3.05e+03  1.349e+02  C2-Nr-Ls
# [ INFO  ]       16  -1.29e+02  3.900e+03  1.233e+04  +8.97e+02  +3.05e+03  1.510e+02  C2-Nr-Ls
# [ INFO  ]       17  -1.27e+02  3.855e+03  1.218e+04  +8.95e+02  +3.05e+03  5.431e+00  C2-Nr-Ls
# [ INFO  ]       18  -1.47e+02  2.767e+03  9.098e+03  +8.45e+02  +3.05e+03  1.399e+02  C2-Nr-Ls
# [ INFO  ]       19  -2.97e+01  1.803e+03  5.844e+03  +7.76e+02  +3.05e+03  1.497e+02  C2-Nr-Ls
# [ INFO  ]       20  -1.09e+02  1.626e+03  5.644e+03  +7.68e+02  +3.05e+03  7.221e+00  C2-Nr-Ls
# [ INFO  ]       21  -1.66e+01  8.733e+02  3.230e+03  +6.74e+02  +3.05e+03  1.132e+02  C2-Nr-Ls
# [ INFO  ]       22  -1.21e+01  6.622e+02  2.746e+03  +6.70e+02  +3.05e+03  3.622e+01  C2-Nr-Ls
# [ INFO  ]       23  -2.70e-06  1.659e+02  1.687e+03  +5.67e+02  +3.05e+03  1.246e+02  C2-Nr-Ls
# [ INFO  ]       24  -3.97e-01  1.537e+02  1.641e+03  +5.58e+02  +3.05e+03  2.009e+01  C2-Nr-Ls
# [ INFO  ]       25  -5.38e-07  6.718e+01  1.434e+03  +5.15e+02  +3.05e+03  8.493e+01  C2-Nr-Ls
# [ INFO  ]       26  +3.36e-05  4.286e+01  1.391e+03  +5.15e+02  +3.05e+03  4.810e+01  C2-Nr-Ls
# [ INFO  ]       27  +6.24e-04  1.782e+01  1.384e+03  +5.15e+02  +3.05e+03  7.372e+01  C2-Nr-Ls
# [ INFO  ]       28  +3.14e-04  1.363e+01  1.379e+03  +5.15e+02  +3.05e+03  6.542e+01  C2-Nr-Ls
# [ INFO  ]       29  -9.50e-09  4.381e+00  1.382e+03  +5.15e+02  +3.05e+03  4.904e+01  C2-Nr-Ls
# [ INFO  ]       30  +5.92e-07  2.784e+00  1.380e+03  +5.15e+02  +3.05e+03  2.183e+01  C2-Nr-Ls
# [ INFO  ]       31  +3.58e-06  2.200e+00  1.379e+03  +5.15e+02  +3.05e+03  9.910e+00  C2-Nr-Ls
# [ INFO  ]       32  +1.44e-05  1.016e+00  1.378e+03  +5.15e+02  +3.05e+03  2.101e+01  C2-Nr-Ls
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +1.38e+03 W m-2
# [ INFO  ]     total flux at TOA  = +1.07e+03 W m-2
# [ INFO  ]     total flux at BOA  = +1.07e+03 W m-2
# [ INFO  ]     column max. loss   = +1.24e+00 W m-2  (+1.16e-01 %)
# [ INFO  ]     final cost value   = +1.02e+00 W m-2
# [ INFO  ]     surf temperature   = 3050.000  K
# Solver success? true

# %%
out = joinpath(output_dir, "base.ncdf")
dump.write_ncdf(atmos, out);

# %% [markdown]
# Plot this profile, to check that it looks reasonable...

# %%
plotting.plot_pt(atmos, "")

# %% [markdown]
# This shows convection from the surface and condensation in the upper atmosphere. This is because there's large upward energy flux as the planet attempts to cool down under the modest instellation.

# %% [markdown]
# ### Run the model for a range of surface temperatures
# Note that the solver will not print each step to the notebook, to avoid clutter here.

# %%
num_loops = 10
tmp_arr = range(start=3000.0, stop=1000.0, length=num_loops)
atm_arr = atmosphere.Atmos_t[]

@printf("Running model for %d samples... \n", num_loops)

for (i,tmp) in enumerate(tmp_arr)
    # Set new surface temperature 
    @printf("Running model for tmp_surf = %.1f K \n",tmp)
    atmos.tmp_surf = tmp 

    # Help solver by changing initial guess
    clamp!(atmos.tmpl, 0.0, tmp)
    clamp!(atmos.tmp, 0.0, tmp)

    # Run model
    solver_success = nl.solve_energy!(atmos, 
                                    sol_type=1,         
                                    sens_heat=true,   
                                    latent=true,        
                                    method=1,           
                                    dx_max=500.0,        # Smaller steps
                                    linesearch=true ,   
                                    save_frames=false, modplot=1,
                                    modprint=0,
                                    conv_atol=0.1  
                                    )

    # Store result
    push!(atm_arr, deepcopy(atmos))

    @printf("--------------------------------- \n")
end 
println("Done!")
# Out:
# Running model for 10 samples...
# Running model for tmp_surf = 3000.0 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 3000.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +1.24e+03 W m-2
# [ INFO  ]     total flux at TOA  = +9.28e+02 W m-2
# [ INFO  ]     total flux at BOA  = +9.28e+02 W m-2
# [ INFO  ]     column max. loss   = +1.19e-02 W m-2  (+1.28e-03 %)
# [ INFO  ]     final cost value   = +1.28e-02 W m-2
# [ INFO  ]     surf temperature   = 3000.000  K
# ---------------------------------
# Running model for tmp_surf = 2777.8 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2777.78 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +8.03e+02 W m-2
# [ INFO  ]     total flux at TOA  = +4.94e+02 W m-2
# [ INFO  ]     total flux at BOA  = +4.94e+02 W m-2
# [ INFO  ]     column max. loss   = +3.54e-03 W m-2  (+7.16e-04 %)
# [ INFO  ]     final cost value   = +3.72e-03 W m-2
# [ INFO  ]     surf temperature   = 2777.778  K
# ---------------------------------
# Running model for tmp_surf = 2555.6 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2555.56 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +5.76e+02 W m-2
# [ INFO  ]     total flux at TOA  = +2.67e+02 W m-2
# [ INFO  ]     total flux at BOA  = +2.67e+02 W m-2
# [ INFO  ]     column max. loss   = +6.45e-02 W m-2  (+2.42e-02 %)
# [ INFO  ]     final cost value   = +9.13e-02 W m-2
# [ INFO  ]     surf temperature   = 2555.556  K
# ---------------------------------
# Running model for tmp_surf = 2333.3 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2333.33 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.63e+02 W m-2
# [ INFO  ]     total flux at TOA  = +1.54e+02 W m-2
# [ INFO  ]     total flux at BOA  = +1.54e+02 W m-2
# [ INFO  ]     column max. loss   = +7.45e-03 W m-2  (+4.85e-03 %)
# [ INFO  ]     final cost value   = +1.03e-02 W m-2
# [ INFO  ]     surf temperature   = 2333.333  K
# ---------------------------------
# Running model for tmp_surf = 2111.1 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2111.11 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.16e+02 W m-2
# [ INFO  ]     total flux at TOA  = +1.07e+02 W m-2
# [ INFO  ]     total flux at BOA  = +1.07e+02 W m-2
# [ INFO  ]     column max. loss   = +8.35e-02 W m-2  (+7.83e-02 %)
# [ INFO  ]     final cost value   = +1.17e-01 W m-2
# [ INFO  ]     surf temperature   = 2111.111  K
# ---------------------------------
# Running model for tmp_surf = 1888.9 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1888.89 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +3.99e+02 W m-2
# [ INFO  ]     total flux at TOA  = +9.00e+01 W m-2
# [ INFO  ]     total flux at BOA  = +9.00e+01 W m-2
# [ INFO  ]     column max. loss   = +1.49e-02 W m-2  (+1.66e-02 %)
# [ INFO  ]     final cost value   = +1.60e-02 W m-2
# [ INFO  ]     surf temperature   = 1888.889  K
# ---------------------------------
# Running model for tmp_surf = 1666.7 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1666.67 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +3.95e+02 W m-2
# [ INFO  ]     total flux at TOA  = +8.54e+01 W m-2
# [ INFO  ]     total flux at BOA  = +8.54e+01 W m-2
# [ INFO  ]     column max. loss   = +4.59e-02 W m-2  (+5.37e-02 %)
# [ INFO  ]     final cost value   = +5.52e-02 W m-2
# [ INFO  ]     surf temperature   = 1666.667  K
# ---------------------------------
# Running model for tmp_surf = 1444.4 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1444.44 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +3.94e+02 W m-2
# [ INFO  ]     total flux at TOA  = +8.45e+01 W m-2
# [ INFO  ]     total flux at BOA  = +8.45e+01 W m-2
# [ INFO  ]     column max. loss   = +1.54e-01 W m-2  (+1.82e-01 %)
# [ INFO  ]     final cost value   = +1.67e-01 W m-2
# [ INFO  ]     surf temperature   = 1444.444  K
# ---------------------------------
# Running model for tmp_surf = 1222.2 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1222.22 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +3.94e+02 W m-2
# [ INFO  ]     total flux at TOA  = +8.43e+01 W m-2
# [ INFO  ]     total flux at BOA  = +8.43e+01 W m-2
# [ INFO  ]     column max. loss   = +2.54e-02 W m-2  (+3.01e-02 %)
# [ INFO  ]     final cost value   = +3.10e-02 W m-2
# [ INFO  ]     surf temperature   = 1222.222  K
# ---------------------------------
# Running model for tmp_surf = 1000.0 K
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1000.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +3.93e+02 W m-2
# [ INFO  ]     total flux at TOA  = +8.42e+01 W m-2
# [ INFO  ]     total flux at BOA  = +8.42e+01 W m-2
# [ INFO  ]     column max. loss   = +7.98e-02 W m-2  (+9.48e-02 %)
# [ INFO  ]     final cost value   = +8.22e-02 W m-2
# [ INFO  ]     surf temperature   = 1000.000  K
# ---------------------------------
# Done!

# %% [markdown]
# ### Make plot of temperature profiles

# %%
fontsize=12
linewidth=1.5;

# %%
arr_P = atmos.pl .* 1.0e-5 # Convert Pa to bar
ylims  = (arr_P[1], arr_P[end])
yticks = 10.0 .^ round.(Int,range( log10(ylims[1]), stop=log10(ylims[2]), step=1))

plt = plot(framestyle=:box, size=(700,500), dpi=300, 
                leg=:topright, legcolumn=-1,
                tickfontsize=fontsize, guidefontsize=fontsize, 
                legendfontsize=fontsize, leg_title="Ts [K]")

p = Plots.palette(:viridis, num_loops)
for (i,this_atm) in enumerate(atm_arr)
    plot!(plt, this_atm.tmpl, this_atm.pl* 1.0e-5, lc=p[i], linewidth=linewidth, label=@sprintf("%d",this_atm.tmp_surf))
end 

xlabel!(plt, "Temperature [K]")
xaxis!(plt, minorgrid=true)
ylabel!(plt, "Pressure [bar]")
yflip!(plt)
yaxis!(plt, yscale=:log10, ylims=ylims, yticks=yticks)
display(plt)
savefig(plt,joinpath(output_dir,"profiles.pdf"))
# Out:
# "/tmp/agni_notebook/profiles.pdf"

# %% [markdown]
# ### Make plot of OLR vs $T_s$

# %%
# Collect data
olr_arr = Float64[]
tot_arr = Float64[]
for this_atm in atm_arr
    push!(olr_arr, this_atm.flux_u_lw[1])
    push!(tot_arr, this_atm.flux_tot[1])
end

# %%
# Make plot
plt = plot(framestyle=:box, size=(700,450),
            tickfontsize=fontsize, guidefontsize=fontsize, legendfontsize=fontsize,
            xlims=(tmp_arr[end]-50, tmp_arr[1]+50),
            ylims=(-10.0, maximum(olr_arr)+50))

hline!(plt, [281.0], label="S-N limit", color="black", linestyle=:dash)

# Plot curves
marker = (:circle,4)
plot!(plt, tmp_arr, olr_arr, linewidth=linewidth, marker=marker, label="OLR", color="red")
plot!(plt, tmp_arr, tot_arr, linewidth=linewidth, marker=marker, label="Total", color="blue")

# Decorate
xlabel!(plt, "Surface temperature [K]")
ylabel!(plt, "Energy flux [W m⁻²]")
xaxis!(plt, minorgrid=true)
display(plt)
savefig(plt,joinpath(output_dir,"curve.pdf"))
println("Done!")
# Out:
# Done!
