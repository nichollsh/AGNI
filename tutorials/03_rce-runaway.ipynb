# %% [markdown]
# ## Calculate OLR versus $T_s$ with radiative-convective atmospheres

# %% [markdown]
# ### Import things
# This assumes that SOCRATES is installed at `AGNI/socrates/`. Modify this as required.

# %%
# Set directory
ROOT_DIR = abspath(joinpath(pwd(),"../"))
ENV["RAD_DIR"] = joinpath(ROOT_DIR,"socrates")
# Out:
# "/Users/nichollsh/Projects/AGNI/socrates"

# %%
# Import system packages
using Printf
using Plots

# Import AGNI
using AGNI
import AGNI.atmosphere as atmosphere
import AGNI.solver as nl
import AGNI.dump as dump
import AGNI.plotting as plotting

# Use Normal-level logging from AGNI module
AGNI.setup_logging("",1)

# %% [markdown]
# ### Define atmosphere parameters

# %%
# Configuration options
instellation    = 1360.0  # Solar constant [W m-2]
gravity         = 9.81
radius          = 6.37e6
nlev_centre     = 30
p_surf          = 270.0     # bar
t_surf          = 3000.0
p_top           = 1e-5      # bar 
mole_fractions  = Dict([("H2O", 1.0)])
condensates     = ["H2O"]

spectral_file = joinpath(ROOT_DIR,"res/spectral_files/Frostflow/256/Frostflow.sf")
star_file     = joinpath(ROOT_DIR,"res/stellar_spectra/sun.txt");

# %%
# Create output directory
output_dir = "/tmp/agni_notebook/"
rm(output_dir,force=true,recursive=true)
mkdir(output_dir);

# %% [markdown]
# ### Initialise the atmosphere

# %%
# Setup atmosphere
atmos = atmosphere.Atmos_t()
atmosphere.setup!(atmos, ROOT_DIR, output_dir, 
                        spectral_file,
                        instellation, 0.375, 0.0, 48.19,
                        t_surf,  
                        gravity, radius,
                        nlev_centre, p_surf, p_top,
                        mf_dict=mole_fractions,
                        condensates=condensates,
                        flag_gcontinuum=true,
                        thermo_functions=false
                        )
atmosphere.allocate!(atmos, star_file)
# Out:
# [ INFO  ] Composition set by dict
# [ INFO  ]     added gas H2O
# [ INFO  ] Inserting stellar spectrum

# %% [markdown]
# ### Run the model for a high-temperature case
# This provides an initial guess from which later simulations will be initialised

# %%
atmos.tmp_surf = 3050.0
atmos.tmpl[:] .= 3050
atmos.tmp[:] .= 3050;

# %%
solver_success = nl.solve_energy!(atmos, 
                                    sol_type=1,         # Conserve energy, but with fixed surface temperature
                                    sens_heat=true,    # Do not include sensible heat transport
                                    latent=true,        # Include condensation
                                    method=1,           # Use the Newton-Raphson method
                                    dx_max=400.0,       # Allow large step sizes because of the poor initial guess
                                    linesearch=true ,   # Enable Linesearch
                                    save_frames=false, modplot=1, # disable plotting 
                                    conv_atol=0.1
                                    )
println("Solver success? $solver_success")
# Out:
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 3050.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]        1  -3.50e+04  1.108e+06  3.217e+06  +2.87e+03  +3.05e+03  4.000e+02  C2-Nr
# [ INFO  ]        2  -2.06e+04  6.398e+05  1.889e+06  +2.64e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        3  -1.08e+04  3.313e+05  9.965e+05  +2.40e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        4  -5.08e+03  1.582e+05  4.890e+05  +2.16e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        5  -2.95e+03  7.857e+04  2.422e+05  +1.92e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        6  -1.37e+03  3.902e+04  1.212e+05  +1.67e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        7  -6.75e+02  1.963e+04  6.351e+04  +1.38e+03  +3.05e+03  3.999e+02  C2-Nr-Ls
# [ INFO  ]        8  -4.95e+02  1.304e+04  4.451e+04  +1.20e+03  +3.05e+03  1.959e+02  C2-Nr-Ls
# [ INFO  ]        9  -5.35e+02  1.245e+04  4.292e+04  +1.19e+03  +3.05e+03  2.453e+01  C2-Nr-Ls
# [ INFO  ]       10  -5.65e+02  1.107e+04  3.892e+04  +1.14e+03  +3.05e+03  7.403e+01  C2-Nr-Ls
# [ INFO  ]       11  -4.78e+02  8.921e+03  3.256e+04  +1.09e+03  +3.05e+03  9.878e+01  C2-Nr-Ls
# [ INFO  ]       12  -3.36e+02  6.564e+03  2.554e+04  +1.01e+03  +3.05e+03  1.366e+02  C2-Nr-Ls
# [ INFO  ]       13  -1.88e+02  4.354e+03  1.907e+04  +9.44e+02  +3.05e+03  1.400e+02  C2-Nr-Ls
# [ INFO  ]       14  -1.79e+02  3.881e+03  1.757e+04  +9.27e+02  +3.05e+03  4.454e+01  C2-Nr-Ls
# [ INFO  ]       15  -1.14e+02  2.976e+03  1.466e+04  +8.83e+02  +3.05e+03  1.110e+02  C2-Nr-Ls
# [ INFO  ]       16  -4.05e+01  2.206e+03  1.171e+04  +8.23e+02  +3.05e+03  1.090e+02  C2-Nr-Ls
# [ INFO  ]       17  -4.79e+01  1.436e+03  1.010e+04  +7.85e+02  +3.05e+03  5.987e+01  C2-Nr-Ls
# [ INFO  ]       18  -3.55e+01  1.128e+03  9.128e+03  +7.61e+02  +3.05e+03  4.643e+01  C2-Nr-Ls
# [ INFO  ]       19  +5.12e-02  6.105e+02  7.351e+03  +6.94e+02  +3.05e+03  1.079e+02  C2-Nr-Ls
# [ INFO  ]       20  +3.21e-04  1.351e+02  6.596e+03  +6.93e+02  +3.05e+03  1.107e+02  C2-Nr-Ls
# [ INFO  ]       21  +2.28e-05  4.197e+01  6.426e+03  +6.94e+02  +3.05e+03  9.982e+01  C2-Nr-Ls
# [ INFO  ]       22  +4.29e-06  2.317e+01  6.385e+03  +6.94e+02  +3.05e+03  6.192e+01  C2-Nr-Ls
# [ INFO  ]       23  +3.67e-05  6.762e+00  6.379e+03  +6.94e+02  +3.05e+03  7.393e+01  C2-Nr-Ls
# [ INFO  ]       24  +1.25e-05  1.556e+00  6.376e+03  +6.94e+02  +3.05e+03  5.520e+01  C2-Nr-Ls
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +6.38e+03 W m-2
# [ INFO  ]     total flux at TOA  = +6.04e+03 W m-2
# [ INFO  ]     total flux at BOA  = +6.04e+03 W m-2
# [ INFO  ]     column max. loss   = +2.20e+00 W m-2  (+3.64e-02 %)
# [ INFO  ]     final cost value   = +1.56e+00 W m-2
# [ INFO  ]     surf temperature   = 3050.000  K
# Solver success? true

# %%
out = joinpath(output_dir, "base.ncdf")
dump.write_ncdf(atmos, out);

# %% [markdown]
# Plot this profile, to check that it looks reasonable...

# %%
plotting.plot_pt(atmos, "")

# %% [markdown]
# This shows convection from the surface and condensation in the upper atmosphere. This is because there's large upward energy flux as the planet attempts to cool down under the modest instellation.

# %% [markdown]
# ### Run the model for a range of surface temperatures
# Note that the solver will not print each step to the notebook, to avoid clutter here.

# %%
num_loops = 10
tmp_arr = range(start=3000.0, stop=1500.0, length=num_loops)
atm_arr = atmosphere.Atmos_t[]

println("Running model for $num_loops samples...")

for (i,tmp) in enumerate(tmp_arr)
    # Set new surface temperature 
    println("Running model for tmp_surf = $tmp")
    atmos.tmp_surf = tmp 

    # Help solver by changing initial guess
    clamp!(atmos.tmpl, 0.0, tmp)
    clamp!(atmos.tmp, 0.0, tmp)

    # Run model
    solver_success = nl.solve_energy!(atmos, 
                                    sol_type=1,         
                                    sens_heat=true,   
                                    latent=true,        
                                    method=1,           
                                    dx_max=300.0,        # Smaller steps
                                    linesearch=true ,   
                                    save_frames=false, modplot=1,
                                    modprint=0,
                                    conv_atol=0.1  
                                    )

    # Store result
    push!(atm_arr, deepcopy(atmos))

    println("---------------------------------")
end 
println("Done!")
# Out:
# Running model for 10 samples...
# Running model for tmp_surf = 3000.0
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 3000.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +5.29e+03 W m-2
# [ INFO  ]     total flux at TOA  = +4.95e+03 W m-2
# [ INFO  ]     total flux at BOA  = +4.95e+03 W m-2
# [ INFO  ]     column max. loss   = +4.40e-03 W m-2  (+8.90e-05 %)
# [ INFO  ]     final cost value   = +5.67e-03 W m-2
# [ INFO  ]     surf temperature   = 3000.000  K
# ---------------------------------
# Running model for tmp_surf = 2833.3333333333335
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2833.33 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +2.85e+03 W m-2
# [ INFO  ]     total flux at TOA  = +2.51e+03 W m-2
# [ INFO  ]     total flux at BOA  = +2.51e+03 W m-2
# [ INFO  ]     column max. loss   = +4.73e-01 W m-2  (+1.89e-02 %)
# [ INFO  ]     final cost value   = +6.69e-01 W m-2
# [ INFO  ]     surf temperature   = 2833.333  K
# ---------------------------------
# Running model for tmp_surf = 2666.6666666666665
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2666.67 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +1.55e+03 W m-2
# [ INFO  ]     total flux at TOA  = +1.19e+03 W m-2
# [ INFO  ]     total flux at BOA  = +1.19e+03 W m-2
# [ INFO  ]     column max. loss   = +4.45e-01 W m-2  (+3.73e-02 %)
# [ INFO  ]     final cost value   = +5.91e-01 W m-2
# [ INFO  ]     surf temperature   = 2666.667  K
# ---------------------------------
# Running model for tmp_surf = 2500.0
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2500.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +9.00e+02 W m-2
# [ INFO  ]     total flux at TOA  = +5.23e+02 W m-2
# [ INFO  ]     total flux at BOA  = +5.23e+02 W m-2
# [ INFO  ]     column max. loss   = +2.52e-01 W m-2  (+4.82e-02 %)
# [ INFO  ]     final cost value   = +3.48e-01 W m-2
# [ INFO  ]     surf temperature   = 2500.000  K
# ---------------------------------
# Running model for tmp_surf = 2333.3333333333335
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2333.33 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +6.08e+02 W m-2
# [ INFO  ]     total flux at TOA  = +2.08e+02 W m-2
# [ INFO  ]     total flux at BOA  = +2.08e+02 W m-2
# [ INFO  ]     column max. loss   = +2.72e-03 W m-2  (+1.31e-03 %)
# [ INFO  ]     final cost value   = +3.12e-03 W m-2
# [ INFO  ]     surf temperature   = 2333.333  K
# ---------------------------------
# Running model for tmp_surf = 2166.6666666666665
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2166.67 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.82e+02 W m-2
# [ INFO  ]     total flux at TOA  = +7.01e+01 W m-2
# [ INFO  ]     total flux at BOA  = +7.01e+01 W m-2
# [ INFO  ]     column max. loss   = +4.52e-03 W m-2  (+6.44e-03 %)
# [ INFO  ]     final cost value   = +5.95e-03 W m-2
# [ INFO  ]     surf temperature   = 2166.667  K
# ---------------------------------
# Running model for tmp_surf = 2000.0
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 2000.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.35e+02 W m-2
# [ INFO  ]     total flux at TOA  = +1.47e+01 W m-2
# [ INFO  ]     total flux at BOA  = +1.47e+01 W m-2
# [ INFO  ]     column max. loss   = +7.60e-02 W m-2  (+5.14e-01 %)
# [ INFO  ]     final cost value   = +7.42e-02 W m-2
# [ INFO  ]     surf temperature   = 2000.000  K
# ---------------------------------
# Running model for tmp_surf = 1833.3333333333333
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1833.33 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.19e+02 W m-2
# [ INFO  ]     total flux at TOA  = -5.38e+00 W m-2
# [ INFO  ]     total flux at BOA  = -5.38e+00 W m-2
# [ INFO  ]     column max. loss   = +5.59e-03 W m-2  (-1.04e-01 %)
# [ INFO  ]     final cost value   = +8.34e-03 W m-2
# [ INFO  ]     surf temperature   = 1833.333  K
# ---------------------------------
# Running model for tmp_surf = 1666.6666666666667
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1666.67 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.13e+02 W m-2
# [ INFO  ]     total flux at TOA  = -1.22e+01 W m-2
# [ INFO  ]     total flux at BOA  = -1.22e+01 W m-2
# [ INFO  ]     column max. loss   = +3.14e-02 W m-2  (-2.58e-01 %)
# [ INFO  ]     final cost value   = +4.17e-02 W m-2
# [ INFO  ]     surf temperature   = 1666.667  K
# ---------------------------------
# Running model for tmp_surf = 1500.0
# [ INFO  ]     sol_type = 1
# [ INFO  ]     tmp_surf = 1500.00 K
# [ INFO  ]     step  resid_med  resid_2nm  flux_OLR   xvals_med  xvals_max  |dx|_max   flags
# [ INFO  ]     success
# [ INFO  ]     outgoing LW flux   = +4.11e+02 W m-2
# [ INFO  ]     total flux at TOA  = -1.43e+01 W m-2
# [ INFO  ]     total flux at BOA  = -1.43e+01 W m-2
# [ INFO  ]     column max. loss   = +9.05e-03 W m-2  (-6.32e-02 %)
# [ INFO  ]     final cost value   = +9.18e-03 W m-2
# [ INFO  ]     surf temperature   = 1500.000  K
# ---------------------------------
# Done!

# %% [markdown]
# ### Make plot of temperature profiles

# %%
fontsize=12
linewidth=1.5;

# %%
arr_P = atmos.pl .* 1.0e-5 # Convert Pa to bar
ylims  = (arr_P[1], arr_P[end])
yticks = 10.0 .^ round.(Int,range( log10(ylims[1]), stop=log10(ylims[2]), step=1))

plt = plot(framestyle=:box, size=(700,500), dpi=300, 
                leg=:topright, legcolumn=-1,
                tickfontsize=fontsize, guidefontsize=fontsize, 
                legendfontsize=fontsize, leg_title="Ts [K]")

p = Plots.palette(:viridis, num_loops)
for (i,this_atm) in enumerate(atm_arr)
    plot!(plt, this_atm.tmpl, this_atm.pl* 1.0e-5, lc=p[i], linewidth=linewidth, label=@sprintf("%d",this_atm.tmp_surf))
end 

xlabel!(plt, "Temperature [K]")
xaxis!(plt, minorgrid=true)
ylabel!(plt, "Pressure [bar]")
yflip!(plt)
yaxis!(plt, yscale=:log10, ylims=ylims, yticks=yticks)
display(plt)
savefig(plt,joinpath(output_dir,"profiles.pdf"))
# Out:
# "/tmp/agni_notebook/profiles.pdf"

# %% [markdown]
# ### Make plot of OLR vs $T_s$

# %%
plt = plot(framestyle=:box, size=(700,450),
            tickfontsize=fontsize, guidefontsize=fontsize, legendfontsize=fontsize,
            xlims=(tmp_arr[end]-50, tmp_arr[1]+50))

olr_arr = Float64[]
tot_arr = Float64[]
for this_atm in atm_arr
    push!(olr_arr, this_atm.flux_u_lw[1])
    push!(tot_arr, this_atm.flux_tot[1])
end 

hline!(plt, [281.0], label="S-N limit", color="black", linestyle=:dash)

# Plot results
marker = (:circle,4)
plot!(plt, tmp_arr, olr_arr, linewidth=linewidth, marker=marker, label="OLR", color="red")
plot!(plt, tmp_arr, tot_arr, linewidth=linewidth, marker=marker, label="Total", color="blue")

xlabel!(plt, "Surface temperature [K]")
ylabel!(plt, "Energy flux [W m⁻²]")
xaxis!(plt, minorgrid=true)
display(plt)
savefig(plt,joinpath(output_dir,"curve.pdf"))
println("Done!")
# Out:
# Done!
